# %%
print("Hello world")
# Out:
# Hello world

# %%
age = True
print(age)
# Out:
# True

# %%
subject = ["math","chem","urdu"]
print(subject[2])
# Out:
# urdu

# %%
person ={}
person["name"] = "Ali"
print(person["name"])
# Out:
# Ali

# %%
person={"name":"Ali","age":23}
print(person["age"])
# Out:
# 23

# %%
answer = 5
answer = answer + 1
print(answer)
# Out:
# 6

# %%
result = not(10>3 or 0>10)
print(result)
# Out:
# False

# %%
age=20
isCitizen = False
if (age>=18) and (isCitizen):
  print("is legal")
elif age>=15:
  print("asdsa")
else:
  print("not legal")
# Out:
# asdsa

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
subject = ["math","chem","urdu"]
for i in subject:
  print(i)
# Out:
# math
# chem
# urdu

# %%
subject = ["math","chem","urdu"]
for i in range(len(subject)):
  print(i, subject[i])
# Out:
# 0 math
# 1 chem
# 2 urdu

# %%
person = {"name": "Ali", "age": 20}
for i in person:
   print(i,person[i])
# Out:
# name Ali
# age 20

# %%
person = {"name": "Ali", "age": 20}
for i,val in person.items():
   print(i,val)
# Out:
# name Ali
# age 20

# %%
for i in range(2):
  print(i)
# Out:
# 0
# 1

# %%
for i in range(2):
  for j in range(2):
    print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
for i in range(10,4,-2):
  print(i)
# Out:
# 10
# 8
# 6

# %%
count = 0
while count <5:
  print(count)
  count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def greet(name,age):
  # print(f"hello {name} ur age is {age}")
  # print("hello " + name + " ur age " + str(age))
  print("hello" , name , "ur age" , age)

greet("ali",20)
# Out:
# hello ali ur age 20

# %%
welcome = lambda name,age: print("hello" , name , "ur age" , age)

welcome("ali",20)
# Out:
# hello ali ur age 20

# %%
numbers=[4,5,6,7,8]
def average(numbers):
  return sum(numbers)/len(numbers)

print(average(numbers))
# Out:
# 6.0

# %%
avg = lambda numbers: sum(numbers)/len(numbers)

print(average(numbers))
# Out:
# 6.0

# %%
name = input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-1946370410> in <cell line: 0>()
# ----> 1 name = input()
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
name = input("enter ur name")
print(f"welcome {name}")
# Out:
# enter ur nameali
# welcome ali

# %%
with open("1.txt","w") as file:
  file.write("hi")

with open("1.txt","a") as file:
  file.write("\nhello")

with open("1.txt","r") as file:
  # text = file.read()
  print(file.read())

file = open("1.txt","r")
for line in file:
  print(line)

file.close()
# Out:
# hi
# hello
